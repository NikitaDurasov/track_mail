# %%
import numpy as np 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
errG = [0.1, 0.22, 1.48, 0.45, 0.16, 0.81, 0.35, 1.01, 0.48,
        0.59, 0.72, 0.73, 0.76, 0.94, 0.86, 1.05, 0.8, 0.98,
        0.97, 1.05, 1.08, 0.97, 0.97, 1., 1.04, 1.04, 1.07,
        1.05, 0.99, 1.1, 1.02, 1.08, 1.03, 1.03, 1.09, 1.09,
        0.95, 1.07, 1.08, 1.24, 1.03, 1.03, 0.99, 1.19, 1.18,
        1.03, 0.94, 1.07, 0.97, 0.99, 1.08, 1.24, 0.86, 0.8,
        1.13, 1.23, 1.01, 1.04, 1.04, 0.72, 1.05, 0.99, 1.14, 
        1.19, 1.1, 1.05, 1.02, 1.06, 0.91, 0.85, 0.96, 0.78, 
        1.03, 1.05, 1.17, 0.90, 1.1, 0.87, 1.11, 0.99, 0.99,
        1.05, 1.18, 0.81, 1.57, 0.8, 0.86, 0.99, 1.13, 1.05,
        1.16, 1.21, 1.19, 1.24, 1.16, 1.01, 1.13, 0.97, 0.88,
        0.92, 1.15, 1.24]

# %%
fig = plt.figure()
plt.plot(range(len(errG)), errG)
plt.title("Gen error per 200 iteration (15 dots = 1 epoch)")
plt.ylabel("Error")
plt.grid()
plt.xlabel("iterations")
plt.xticks(range(0, 120, 15), ["epoch " + str(x) for x in range(8)])
fig.savefig("LSGAN_G_error.pdf", format='pdf')

# %%
errD = np.array([(2.65, 2.64), (1.24, 1.63), (0.89, 0.05), (1.85, 0.3),
        (0.45, 0.65), (0.53, 0.02), (0.51, 0.34), (0.15, 0.0),
        (0.23, 0.18), (0.2, 0.11), (0.07, 0.05), (0.28, 0.06),
        (0.23, 0.07), (0.09, 0.01), (0.05, 0.03), (0.06, 0),
        (0.07, 0.04), (0.05, 0), (0.06, 0), (0.15, 0), (0.03, 0),
        (0.03, 0.01), (0.04, 0.02), (0.02, 0.01), (0.01, 0),
        (0.04, 0.02), (0.02, 0), (0.03, 0), (0.04, 0.03), (0.02, 0),
        (0.07, 0), (0.03, 0), (0.01, 0), (0.01, 0), (0.01, 0),
        (0, 0), (0.11, 0.01), (0.01, 0.03), (0.01, 0), (0.02, 0),
        (0.01, 0.03), (0.01, 0), (0.02, 0), (0.01, 0.01), (0.01, 0.01)])

# %%
fig = plt.figure()
plt.plot(range(len(errD[:, 1])), errD[:, 1])
plt.grid()
plt.title("Discr_z error per 200 iteration (15 dots = 1 epoch)")
plt.ylabel("Error")
plt.xlabel("iterations")
plt.xticks(range(0, 50, 15), ["epoch " + str(x) for x in range(10)])
fig.savefig("LSGAN_D_z_error.pdf", format='pdf')

# %%
fig = plt.figure()
plt.plot(range(len(errD[:, 0])), errD[:, 0])
plt.scatter(range(len(errD[:, 0])), errD[:, 0], s=5, c=)
plt.grid()
plt.title("Discr_x error per 200 iteration (15 dots = 1 epoch)")
plt.ylabel("Error")
plt.xlabel("iterations")
plt.xticks(range(0, 50, 15), ["epoch " + str(x) for x in range(10)])
fig.savefig("LSGAN_D_x_error.pdf", format='pdf')
